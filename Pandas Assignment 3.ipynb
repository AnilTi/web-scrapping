# %%
import pandas as pd

# %%
mlbsalaries=pd.read_csv('mlbsalaries.csv')

# %%
type(mlbsalaries)
# Out:
# pandas.core.frame.DataFrame

# %%
mlbsalaries
# Out:
#        Year           Player   Salary           Position                Team
# 0      1988        Mike Witt  1400000            Pitcher  Los Angeles Angels
# 1      1988  George Hendrick   989333         Outfielder  Los Angeles Angels
# 2      1988      Chili Davis   950000         Outfielder  Los Angeles Angels
# 3      1988    Brian Downing   900000  Designated Hitter  Los Angeles Angels
# 4      1988        Bob Boone   883000            Catcher  Los Angeles Angels
# ...     ...              ...      ...                ...                 ...
# 19538  2011   Gustavo Molina   455000            Catcher    New York Yankees
# 19539  2011        Ivan Nova   432900            Pitcher    New York Yankees
# 19540  2011     Colin Curtis   420400         Outfielder    New York Yankees
# 19541  2011    Eduardo Nunez   419300          Shortstop    New York Yankees
# 19542  2011    Reegie Corona   414000     Second Baseman    New York Yankees
#
# [19543 rows x 5 columns]

# %%
m=mlbsalaries

# %%
m
# Out:
#        Year           Player   Salary           Position                Team
# 0      1988        Mike Witt  1400000            Pitcher  Los Angeles Angels
# 1      1988  George Hendrick   989333         Outfielder  Los Angeles Angels
# 2      1988      Chili Davis   950000         Outfielder  Los Angeles Angels
# 3      1988    Brian Downing   900000  Designated Hitter  Los Angeles Angels
# 4      1988        Bob Boone   883000            Catcher  Los Angeles Angels
# ...     ...              ...      ...                ...                 ...
# 19538  2011   Gustavo Molina   455000            Catcher    New York Yankees
# 19539  2011        Ivan Nova   432900            Pitcher    New York Yankees
# 19540  2011     Colin Curtis   420400         Outfielder    New York Yankees
# 19541  2011    Eduardo Nunez   419300          Shortstop    New York Yankees
# 19542  2011    Reegie Corona   414000     Second Baseman    New York Yankees
#
# [19543 rows x 5 columns]

# %%
m.shape
# Out:
# (19543, 5)

# %%
m.columns
# Out:
# Index(['Year', 'Player', 'Salary', 'Position', 'Team'], dtype='object')

# %%
# How to find total number of records ?

# %%
m.shape[0]
# Out:
# 19543

# %%
# 2. How to find out total number of columns?

# %%
m.shape[1]
# Out:
# 5

# %%
# 3. Display all columns names ?

# %%
m.columns
# Out:
# Index(['Year', 'Player', 'Salary', 'Position', 'Team'], dtype='object')

# %%
# 4. Show only maximum salary value ?

# %%
import numpy as np

# %%
m['Salary'].max()
# Out:
# 33000000

# %%
# 5. Show only mimmum salary value ?

# %%
m['Salary'].min()
# Out:
# 62500

# %%
# 6. Show Maximim salary complete record ?

# %%
m.sort_values(by='Salary',ascending=False).head(2)
# Out:
#        Year          Player    Salary       Position              Team
# 17846  2009  Alex Rodriguez  33000000  Third Baseman  New York Yankees
# 18675  2010  Alex Rodriguez  33000000  Third Baseman  New York Yankees

# %%
# method 2
m[m['Salary']==m['Salary'].max()]
# Out:
#        Year          Player    Salary       Position              Team
# 17846  2009  Alex Rodriguez  33000000  Third Baseman  New York Yankees
# 18675  2010  Alex Rodriguez  33000000  Third Baseman  New York Yankees

# %%
# 7. Show Minmum salary complete record ?

# %%
m.sort_values(by='Salary',ascending=True).head(1)
# Out:
#      Year       Player  Salary Position           Team
# 497  1988  Jose Cecena   62500  Pitcher  Texas Rangers

# %%
# method 2
m[m['Salary']==m['Salary'].min()]
# Out:
#      Year           Player  Salary       Position                Team
# 21   1988      Thad Bosley   62500     Outfielder  Los Angeles Angels
# 22   1988      Terry Clark   62500        Pitcher  Los Angeles Angels
# 23   1988  Sherman Corbett   62500        Pitcher  Los Angeles Angels
# 24   1988       Jim Eppard   62500     Outfielder  Los Angeles Angels
# 25   1988     Bryan Harvey   62500        Pitcher  Los Angeles Angels
# ..    ...              ...     ...            ...                 ...
# 654  1988      Russ Morman   62500  First Baseman   Chicago White Sox
# 655  1988        Donn Pall   62500        Pitcher   Chicago White Sox
# 656  1988      Kelly Paris   62500  First Baseman   Chicago White Sox
# 657  1988     Melido Perez   62500        Pitcher   Chicago White Sox
# 658  1988  Steve Rosenberg   62500        Pitcher   Chicago White Sox
#
# [81 rows x 5 columns]

# %%
# 8. Show all record Team Wise Details ?

# %%
m['Team']
# Out:
# 0        Los Angeles Angels
# 1        Los Angeles Angels
# 2        Los Angeles Angels
# 3        Los Angeles Angels
# 4        Los Angeles Angels
#                 ...
# 19538      New York Yankees
# 19539      New York Yankees
# 19540      New York Yankees
# 19541      New York Yankees
# 19542      New York Yankees
# Name: Team, Length: 19543, dtype: object

# %%
#METHOD 2
m.sort_values(by='Team',ascending=True)
# Out:
#        Year            Player   Salary        Position                  Team
# 10573  2001     Damian Miller  1250000         Catcher  Arizona Diamondbacks
# 8835   1999      Lenny Harris  1125000  Second Baseman  Arizona Diamondbacks
# 8836   1999     Greg Colbrunn   900000   First Baseman  Arizona Diamondbacks
# 8837   1999       Gregg Olson   850000         Pitcher  Arizona Diamondbacks
# 8838   1999    Byung-Hyun Kim   762500         Pitcher  Arizona Diamondbacks
# ...     ...               ...      ...             ...                   ...
# 7339   1997   Darrin Fletcher  1350000         Catcher  Washington Nationals
# 7340   1997     Rheal Cormier  1050000         Pitcher  Washington Nationals
# 7341   1997        Dave Veres   725000         Pitcher  Washington Nationals
# 4242   1993  Delino DeShields  1537500  Second Baseman  Washington Nationals
# 13301  2004    Peter Bergeron   300000      Outfielder  Washington Nationals
#
# [19543 rows x 5 columns]

# %%
# 8. Show all record Year Wise Details ?

# %%
m['Year']
# Out:
# 0        1988
# 1        1988
# 2        1988
# 3        1988
# 4        1988
#          ...
# 19538    2011
# 19539    2011
# 19540    2011
# 19541    2011
# 19542    2011
# Name: Year, Length: 19543, dtype: int64

# %%
#METHOD 2
m.sort_values(by='Year',ascending=True)
# Out:
#        Year         Player    Salary        Position                  Team
# 0      1988      Mike Witt   1400000         Pitcher    Los Angeles Angels
# 453    1988       Bob Walk    450000         Pitcher    Pittsburgh Pirates
# 454    1988   Dave Lapoint    425000         Pitcher    Pittsburgh Pirates
# 455    1988      Sid Bream    360000   First Baseman    Pittsburgh Pirates
# 456    1988  R.J. Reynolds    290000      Outfielder    Pittsburgh Pirates
# ...     ...            ...       ...             ...                   ...
# 18984  2011     Barry Zito  18500000         Pitcher  San Francisco Giants
# 18985  2011   Tim Lincecum  14000000         Pitcher  San Francisco Giants
# 18986  2011   Aaron Rowand  13600000      Outfielder  San Francisco Giants
# 18962  2011     Juan Uribe   5295910  Second Baseman   Los Angeles Dodgers
# 19542  2011  Reegie Corona    414000  Second Baseman      New York Yankees
#
# [19543 rows x 5 columns]

# %%
# Show all player names where position = Pitcher ?

# %%
a=m.loc[m[m.Position=='Picther'].index.tolist()]['Player'].unique().tolist()
a
# Out:
# []

# %%
n=m.loc[m[m.Position=='Pitcher'].index.tolist()]['Player'].unique().tolist()
n
# Out:
# ['Mike Witt',
#  'Dan Petry',
#  'Greg Minton',
#  'Kirk McCaskill',
#  'Willie Fraser',
#  'Chuck Finley',
#  'Jack Lazorko',
#  'Stew Cliburn',
#  'Terry Clark',
#  'Sherman Corbett',
#  'Bryan Harvey',
#  'Nolan Ryan',
#  'Dave Smith',
#  'Bob Knepper',
#  'Danny Darwin',
#  'Mike Scott',
#  'Bob Forsch',
#  'Joaquin Andujar',
#  'Larry Andersen',
#  'Jim Deshaies',
#  'Juan Agosto',
#  'Bob Welch',
#  'Rick Honeycutt',
#  'Dennis Eckersley',
#  'Dave Stewart',
#  'Storm Davis',
#  'Gene Nelson',
#  'Matt Young',
#  'Curt Young',
#  'Steve Ontiveros',
#  'Eric Plunk',
#  'Greg Cadaret',
#  'Todd Burns',
#  'Dave Stieb',
#  'Jim Clancy',
#  'Tom Henke',
#  'Mike Flanagan',
#  'Jimmy Key',
#  'John Cerutti',
#  'Jeff Musselman',
#  'David Wells',
#  'Duane Ward',
#  'Tony Castillo',
#  'Bruce Sutter',
#  'Rick Mahler',
#  'Zane Smith',
#  'Jim Acker',
#  'Charlie Puleo',
#  'Paul Assenmacher',
#  'Tom Glavine',
#  'Pete Smith',
#  'Jose Alvarez',
#  'German Jimenez',
# ...

# %%
# How to find out all missing values count in all columns ?

# %%
m.isnull().sum()
# Out:
# Year        0
# Player      0
# Salary      0
# Position    0
# Team        0
# dtype: int64

# %%
# Show Team wise Salaries Total ?

# %%
h = m.groupby(pd.Grouper(key='Team')).sum()
h=['Salary']

# %%
h=a.groupby(pd.Grouper(key='Team')).sum()   # not sure about this one
h['Salary']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\MONUSA~1\AppData\Local\Temp/ipykernel_7996/2953610142.py in <module>
# ----> 1 h=a.groupby(pd.Grouper(key='Team')).sum()   # not sure about this one
#       2 h['Salary']
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
# Count ALL Player Team wise ?

# %%
i = m
